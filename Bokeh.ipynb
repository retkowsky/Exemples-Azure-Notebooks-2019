# %% [markdown]
# # Graphiques avec BOKEH
# http://bokeh.pydata.org/en/latest/

# %%
from math import log, sqrt

# %%
import numpy as np
import pandas as pd
from six.moves import cStringIO as StringIO

# %%
from bokeh.plotting import figure, output_notebook, show

# %%
antibiotics = """
bacteria,                        penicillin, streptomycin, neomycin, gram
Mycobacterium tuberculosis,      800,        5,            2,        negative
Salmonella schottmuelleri,       10,         0.8,          0.09,     negative
Proteus vulgaris,                3,          0.1,          0.1,      negative
Klebsiella pneumoniae,           850,        1.2,          1,        negative
Brucella abortus,                1,          2,            0.02,     negative
Pseudomonas aeruginosa,          850,        2,            0.4,      negative
Escherichia coli,                100,        0.4,          0.1,      negative
Salmonella (Eberthella) typhosa, 1,          0.4,          0.008,    negative
Aerobacter aerogenes,            870,        1,            1.6,      negative
Brucella antracis,               0.001,      0.01,         0.007,    positive
Streptococcus fecalis,           1,          1,            0.1,      positive
Staphylococcus aureus,           0.03,       0.03,         0.001,    positive
Staphylococcus albus,            0.007,      0.1,          0.001,    positive
Streptococcus hemolyticus,       0.001,      14,           10,       positive
Streptococcus viridans,          0.005,      10,           40,       positive
Diplococcus pneumoniae,          0.005,      11,           10,       positive
"""

# %%
drug_color = {
    "Penicillin"   : "#0d3362",
    "Streptomycin" : "#c64737",
    "Neomycin"     : "black",
}

# %%
gram_color = {
    "positive" : "#aeaeb8",
    "negative" : "#e69584",
}

# %%
df = pd.read_csv(StringIO(antibiotics), skiprows=1, skipinitialspace=True, engine='python')

# %%
width = 800
height = 800
inner_radius = 90
outer_radius = 300 - 10

minr = sqrt(log(.001 * 1E4))
maxr = sqrt(log(1000 * 1E4))
a = (outer_radius - inner_radius) / (minr - maxr)
b = inner_radius - a * maxr

big_angle = 2.0 * np.pi / (len(df) + 1)
small_angle = big_angle / 7

# %%
def rad(mic):
    return a * np.sqrt(np.log(mic * 1E4)) + b

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="36011c66-b7e1-4c13-8957-4a01eac9b70a">Loading BokehJS ...</span>
#     </div>

# %%
p = figure(plot_width=width, plot_height=height, toolbar_sticky=False,
           x_axis_type=None, y_axis_type=None,
           x_range=(-420, 420), y_range=(-420, 420),
           min_border=0, outline_line_color="black",
           background_fill_color="#f0e1d2", border_fill_color="#f0e1d2")

# %%
# annular wedges
angles = np.pi/2 - big_angle/2 - df.index.to_series()*big_angle
colors = [gram_color[gram] for gram in df.gram]
p.annular_wedge(0, 0, inner_radius, outer_radius, -big_angle+angles, angles, color=colors)
# Out:
# bokeh.models.renderers.GlyphRenderer(
#     id='f40884de-8a4f-4ece-ad98-d9a563ba5da9',
#     data_source=bokeh.models.sources.ColumnDataSource(
#         id='c8ec1125-5804-4852-a01b-403daa877268',
#         callback=None,
#         data={'start_angle': {'__ndarray__': 'eWh3JypD8D/Iyt29krLkPz+JmVmivdE/TAwiIoOnt79nj6rqY5Hdv95NZoZznOq/A6q7ixo4878ZLURU+yH5vy2wzBzcC/+/oJmqct56AsAr2+7Wzm8FwLUcMzu/ZAjAP153n69ZC8DJn7sDoE4OwKvw/zPIoRDAbxEiZkAcEsA=',
#           'shape': (16,),
#           'dtype': 'float64'},
#          'line_color': ['#e69584',
#           '#e69584',
#           '#e69584',
#           '#e69584',
#           '#e69584',
#           '#e69584',
#           '#e69584',
#           '#e69584',
#           '#e69584',
#           '#aeaeb8',
#           '#aeaeb8',
#           '#aeaeb8',
#           '#aeaeb8',
#           '#aeaeb8',
#           '#aeaeb8',
#           '#aeaeb8'],
#          'fill_color': ['#e69584',
#           '#e69584',
#           '#e69584',
#           '#e69584',
#           '#e69584',
#           '#e69584',
#           '#e69584',
#           '#e69584',
#           '#e69584',
#           '#aeaeb8',
#           '#aeaeb8',
#           '#aeaeb8',
#           '#aeaeb8',
#           '#aeaeb8',
#           '#aeaeb8',
#           '#aeaeb8'],
#          'end_angle': {'__ndarray__': 'juv/7wot9j95aHcnKkPwP8nK3b2SsuQ/QImZWaK90T9QDCIig6e3v2iPqupjkd2/3E1mhnOc6r8EqruLGjjzvxgtRFT7Ifm/LLDMHNwL/7+hmapy3noCwCvb7tbObwXAtRwzO79kCMA/Xnefr1kLwMufuwOgTg7AqvD/M8ihEMA=',
#           'shape': (16,),
#           'dtype': 'float64'}},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         selected=bokeh.models.selections.Selection(
#             id='872318d2-8456-47c1-9dc5-1d6b408b984a',
#             indices=[],
#             js_event_callbacks={},
#             js_property_callbacks={},
#             line_indices=[],
#             multiline_indices={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         selection_policy=bokeh.models.selections.UnionRenderers(
#             id='d4616788-028c-4d25-983c-69e66766dac8',
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     glyph=bokeh.models.glyphs.AnnularWedge(
#         id='6b537bbe-2291-4163-b99e-61e34f0518a5',
#         direction='anticlock',
#         end_angle={'field': 'end_angle', 'units': 'rad'},
#         fill_alpha={'value': 1.0},
#         fill_color={'field': 'fill_color'},
#         inner_radius={'value': 90, 'units': 'data'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha={'value': 1.0},
#         line_cap='butt',
#         line_color={'field': 'line_color'},
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='bevel',
#         line_width={'value': 1},
#         name=None,
#         outer_radius={'value': 290, 'units': 'data'},
#         start_angle={'field': 'start_angle', 'units': 'rad'},
#         subscribed_events=[],
#         tags=[],
#         x={'value': 0},
#         y={'value': 0}),
#     hover_glyph=None,
#     js_event_callbacks={},
#     js_property_callbacks={},
#     level='glyph',
#     muted=False,
#     muted_glyph=None,
#     name=None,
#     nonselection_glyph=bokeh.models.glyphs.AnnularWedge(
#         id='421d29c2-f179-42fd-80d3-a945d6469759',
#         direction='anticlock',
#         end_angle={'field': 'end_angle', 'units': 'rad'},
#         fill_alpha={'value': 0.1},
#         fill_color={'value': '#1f77b4'},
#         inner_radius={'value': 90, 'units': 'data'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha={'value': 0.1},
#         line_cap='butt',
#         line_color={'value': '#1f77b4'},
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='bevel',
#         line_width={'value': 1},
#         name=None,
#         outer_radius={'value': 290, 'units': 'data'},
#         start_angle={'field': 'start_angle', 'units': 'rad'},
#         subscribed_events=[],
#         tags=[],
#         x={'value': 0},
#         y={'value': 0}),
#     selection_glyph=None,
#     subscribed_events=[],
#     tags=[],
#     view=bokeh.models.sources.CDSView(
#         id='b498d40c-a67a-4d89-8717-9347955a609a',
#         filters=[],
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         source=bokeh.models.sources.ColumnDataSource(
#             id='c8ec1125-5804-4852-a01b-403daa877268',
#             callback=None,
#             data={'start_angle': {'__ndarray__': 'eWh3JypD8D/Iyt29krLkPz+JmVmivdE/TAwiIoOnt79nj6rqY5Hdv95NZoZznOq/A6q7ixo4878ZLURU+yH5vy2wzBzcC/+/oJmqct56AsAr2+7Wzm8FwLUcMzu/ZAjAP153n69ZC8DJn7sDoE4OwKvw/zPIoRDAbxEiZkAcEsA=',
#               'shape': (16,),
#               'dtype': 'float64'},
#              'line_color': ['#e69584',
#               '#e69584',
#               '#e69584',
#               '#e69584',
#               '#e69584',
#               '#e69584',
#               '#e69584',
#               '#e69584',
#               '#e69584',
#               '#aeaeb8',
#               '#aeaeb8',
#               '#aeaeb8',
#               '#aeaeb8',
#               '#aeaeb8',
#               '#aeaeb8',
#               '#aeaeb8'],
#              'fill_color': ['#e69584',
#               '#e69584',
#               '#e69584',
#               '#e69584',
#               '#e69584',
#               '#e69584',
#               '#e69584',
#               '#e69584',
#               '#e69584',
#               '#aeaeb8',
#               '#aeaeb8',
#               '#aeaeb8',
#               '#aeaeb8',
#               '#aeaeb8',
#               '#aeaeb8',
#               '#aeaeb8'],
#              'end_angle': {'__ndarray__': 'juv/7wot9j95aHcnKkPwP8nK3b2SsuQ/QImZWaK90T9QDCIig6e3v2iPqupjkd2/3E1mhnOc6r8EqruLGjjzvxgtRFT7Ifm/LLDMHNwL/7+hmapy3noCwCvb7tbObwXAtRwzO79kCMA/Xnefr1kLwMufuwOgTg7AqvD/M8ihEMA=',
#               'shape': (16,),
#               'dtype': 'float64'}},
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             selected=bokeh.models.selections.Selection(
#                 id='872318d2-8456-47c1-9dc5-1d6b408b984a',
#                 indices=[],
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 line_indices=[],
#                 multiline_indices={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             selection_policy=bokeh.models.selections.UnionRenderers(
#                 id='d4616788-028c-4d25-983c-69e66766dac8',
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     visible=True,
#     x_range_name='default',
#     y_range_name='default')

# %%
# small wedges
p.annular_wedge(0, 0, inner_radius, rad(df.penicillin), -big_angle+angles + 5*small_angle, 
                -big_angle+angles+6*small_angle, color=drug_color['Penicillin'])
p.annular_wedge(0, 0, inner_radius, rad(df.streptomycin), -big_angle+angles + 3*small_angle, 
                -big_angle+angles+4*small_angle, color=drug_color['Streptomycin'])
p.annular_wedge(0, 0, inner_radius, rad(df.neomycin), -big_angle+angles + 1*small_angle, 
                -big_angle+angles+2*small_angle, color=drug_color['Neomycin'])
# Out:
# bokeh.models.renderers.GlyphRenderer(
#     id='9ec5c528-2a06-44da-9f8e-71a6f1783e5d',
#     data_source=bokeh.models.sources.ColumnDataSource(
#         id='54808dc6-66b4-4c39-a9aa-503f4179d675',
#         callback=None,
#         data={'start_angle': {'__ndarray__': 'oVZm1m4b8T8Xp7sbHGPmP91BVRW1HtU/p1NmZnBGpL/J1u4uUTDav49xiCjq6+i/27vM3NVf8r/xPlWltkn4vwXC3W2XM/6/jCIzG7wOAsAXZHd/rAMFwKGlu+Oc+AfAK+f/R43tCsC1KESsfeINwCE1RAi3axDA5VVmOi/mEcA=',
#           'shape': (16,),
#           'dtype': 'float64'},
#          'outer_radius': {'__ndarray__': 'm8z7btjvY0D9PDy5w1RpQDjj0CUzIWlABsmM1zIPZUChS31Y0mVsQB0YCXI1nGZAOOPQJTMhaUCyh+QAGnxuQM3Wg944S2RA/HdeznjObkA449AlMyFpQAAAAAAAIHJAAAAAAAAgckCg0sRXLXlhQFhbROgM+V5AoNLEVy15YUA=',
#           'shape': (16,),
#           'dtype': 'float64'},
#          'end_angle': {'__ndarray__': 'yERVhbPz8T9mg5l5pRPoP3v6ENHHf9g/KMXd3ZUIiz8rHjNzPs/Wv0CVqspgO+e/tM3dLZGH8b/KUGb2cXH3v97T7r5SW/2/eKu7w5miAcAD7f8nipcEwI0uRIx6jAfAF3CI8GqBCsChscxUW3YNwJd5iNylNRDAW5qqDh6wEcA=',
#           'shape': (16,),
#           'dtype': 'float64'}},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         selected=bokeh.models.selections.Selection(
#             id='4b863fff-fda3-4cd7-a273-1992da022b30',
#             indices=[],
#             js_event_callbacks={},
#             js_property_callbacks={},
#             line_indices=[],
#             multiline_indices={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         selection_policy=bokeh.models.selections.UnionRenderers(
#             id='505f6e57-8693-4f7f-bf7f-35d777cd42ed',
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     glyph=bokeh.models.glyphs.AnnularWedge(
#         id='8d1dbc9a-a8b8-46ac-bb60-2c3ed4f2bbd2',
#         direction='anticlock',
#         end_angle={'field': 'end_angle', 'units': 'rad'},
#         fill_alpha={'value': 1.0},
#         fill_color={'value': 'black'},
#         inner_radius={'value': 90, 'units': 'data'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha={'value': 1.0},
#         line_cap='butt',
#         line_color={'value': 'black'},
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='bevel',
#         line_width={'value': 1},
#         name=None,
#         outer_radius={'field': 'outer_radius', 'units': 'data'},
#         start_angle={'field': 'start_angle', 'units': 'rad'},
#         subscribed_events=[],
#         tags=[],
#         x={'value': 0},
#         y={'value': 0}),
#     hover_glyph=None,
#     js_event_callbacks={},
#     js_property_callbacks={},
#     level='glyph',
#     muted=False,
#     muted_glyph=None,
#     name=None,
#     nonselection_glyph=bokeh.models.glyphs.AnnularWedge(
#         id='e78e4aaf-ade2-4d35-8f62-babafaa1a7a3',
#         direction='anticlock',
#         end_angle={'field': 'end_angle', 'units': 'rad'},
#         fill_alpha={'value': 0.1},
#         fill_color={'value': '#1f77b4'},
#         inner_radius={'value': 90, 'units': 'data'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha={'value': 0.1},
#         line_cap='butt',
#         line_color={'value': '#1f77b4'},
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='bevel',
#         line_width={'value': 1},
#         name=None,
#         outer_radius={'field': 'outer_radius', 'units': 'data'},
#         start_angle={'field': 'start_angle', 'units': 'rad'},
#         subscribed_events=[],
#         tags=[],
#         x={'value': 0},
#         y={'value': 0}),
#     selection_glyph=None,
#     subscribed_events=[],
#     tags=[],
#     view=bokeh.models.sources.CDSView(
#         id='c1616fde-6bb3-4988-8b72-28e44b2f9f43',
#         filters=[],
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         source=bokeh.models.sources.ColumnDataSource(
#             id='54808dc6-66b4-4c39-a9aa-503f4179d675',
#             callback=None,
#             data={'start_angle': {'__ndarray__': 'oVZm1m4b8T8Xp7sbHGPmP91BVRW1HtU/p1NmZnBGpL/J1u4uUTDav49xiCjq6+i/27vM3NVf8r/xPlWltkn4vwXC3W2XM/6/jCIzG7wOAsAXZHd/rAMFwKGlu+Oc+AfAK+f/R43tCsC1KESsfeINwCE1RAi3axDA5VVmOi/mEcA=',
#               'shape': (16,),
#               'dtype': 'float64'},
#              'outer_radius': {'__ndarray__': 'm8z7btjvY0D9PDy5w1RpQDjj0CUzIWlABsmM1zIPZUChS31Y0mVsQB0YCXI1nGZAOOPQJTMhaUCyh+QAGnxuQM3Wg944S2RA/HdeznjObkA449AlMyFpQAAAAAAAIHJAAAAAAAAgckCg0sRXLXlhQFhbROgM+V5AoNLEVy15YUA=',
#               'shape': (16,),
#               'dtype': 'float64'},
#              'end_angle': {'__ndarray__': 'yERVhbPz8T9mg5l5pRPoP3v6ENHHf9g/KMXd3ZUIiz8rHjNzPs/Wv0CVqspgO+e/tM3dLZGH8b/KUGb2cXH3v97T7r5SW/2/eKu7w5miAcAD7f8nipcEwI0uRIx6jAfAF3CI8GqBCsChscxUW3YNwJd5iNylNRDAW5qqDh6wEcA=',
#               'shape': (16,),
#               'dtype': 'float64'}},
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             selected=bokeh.models.selections.Selection(
#                 id='4b863fff-fda3-4cd7-a273-1992da022b30',
#                 indices=[],
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 line_indices=[],
#                 multiline_indices={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             selection_policy=bokeh.models.selections.UnionRenderers(
#                 id='505f6e57-8693-4f7f-bf7f-35d777cd42ed',
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     visible=True,
#     x_range_name='default',
#     y_range_name='default')

# %%
# circular axes and lables
labels = np.power(10.0, np.arange(-3, 4))
radii = a * np.sqrt(np.log(labels * 1E4)) + b
p.circle(0, 0, radius=radii, fill_color=None, line_color="white")
p.text(0, radii[:-1], [str(r) for r in labels[:-1]], 
       text_font_size="8pt", text_align="center", text_baseline="middle")
# Out:
# bokeh.models.renderers.GlyphRenderer(
#     id='89ad2b99-4dee-4694-9884-5b850110c383',
#     data_source=bokeh.models.sources.ColumnDataSource(
#         id='c4af93d6-f896-4119-9c4c-7b52df0be483',
#         callback=None,
#         data={'text': ['0.001', '0.01', '0.1', '1.0', '10.0', '100.0'],
#          'y': {'__ndarray__': 'AAAAAAAgckDHcwaqNPVtQDjj0CUzIWlABsmM1zIPZUCg0sRXLXlhQBRFOMxxdlxA',
#           'shape': (6,),
#           'dtype': 'float64'}},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         selected=bokeh.models.selections.Selection(
#             id='5a7e00ef-74a2-4ac8-9355-cce3e850a257',
#             indices=[],
#             js_event_callbacks={},
#             js_property_callbacks={},
#             line_indices=[],
#             multiline_indices={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         selection_policy=bokeh.models.selections.UnionRenderers(
#             id='300a6a3b-bf4e-45a2-baae-8e0d4c97fc85',
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     glyph=bokeh.models.glyphs.Text(
#         id='d929cc4a-9f58-48d0-b7ff-ffae0a733d40',
#         angle={'value': 0, 'units': 'rad'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         subscribed_events=[],
#         tags=[],
#         text={'field': 'text'},
#         text_align='center',
#         text_alpha={'value': 1.0},
#         text_baseline='middle',
#         text_color={'value': 'black'},
#         text_font='helvetica',
#         text_font_size={'value': '8pt'},
#         text_font_style='normal',
#         text_line_height=1.2,
#         x={'value': 0},
#         x_offset={'value': 0},
#         y={'field': 'y'},
#         y_offset={'value': 0}),
#     hover_glyph=None,
#     js_event_callbacks={},
#     js_property_callbacks={},
#     level='glyph',
#     muted=False,
#     muted_glyph=None,
#     name=None,
#     nonselection_glyph=bokeh.models.glyphs.Text(
#         id='aac4bee0-eab3-4af2-a67c-a4ecadeca91a',
#         angle={'value': 0, 'units': 'rad'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         subscribed_events=[],
#         tags=[],
#         text={'field': 'text'},
#         text_align='center',
#         text_alpha={'value': 0.1},
#         text_baseline='middle',
#         text_color={'value': 'black'},
#         text_font='helvetica',
#         text_font_size={'value': '8pt'},
#         text_font_style='normal',
#         text_line_height=1.2,
#         x={'value': 0},
#         x_offset={'value': 0},
#         y={'field': 'y'},
#         y_offset={'value': 0}),
#     selection_glyph=None,
#     subscribed_events=[],
#     tags=[],
#     view=bokeh.models.sources.CDSView(
#         id='6cdccdf6-2c59-4a9c-adc5-e2f9864cd141',
#         filters=[],
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         source=bokeh.models.sources.ColumnDataSource(
#             id='c4af93d6-f896-4119-9c4c-7b52df0be483',
#             callback=None,
#             data={'text': ['0.001', '0.01', '0.1', '1.0', '10.0', '100.0'],
#              'y': {'__ndarray__': 'AAAAAAAgckDHcwaqNPVtQDjj0CUzIWlABsmM1zIPZUCg0sRXLXlhQBRFOMxxdlxA',
#               'shape': (6,),
#               'dtype': 'float64'}},
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             selected=bokeh.models.selections.Selection(
#                 id='5a7e00ef-74a2-4ac8-9355-cce3e850a257',
#                 indices=[],
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 line_indices=[],
#                 multiline_indices={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             selection_policy=bokeh.models.selections.UnionRenderers(
#                 id='300a6a3b-bf4e-45a2-baae-8e0d4c97fc85',
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     visible=True,
#     x_range_name='default',
#     y_range_name='default')

# %%
# radial axes
p.annular_wedge(0, 0, inner_radius-10, outer_radius+10, 
                -big_angle+angles, -big_angle+angles, color="black")
# Out:
# bokeh.models.renderers.GlyphRenderer(
#     id='a438457d-9a10-4162-baa8-cc1421f76e9b',
#     data_source=bokeh.models.sources.ColumnDataSource(
#         id='67980bc7-b1fa-4430-9db0-510b3b578259',
#         callback=None,
#         data={'start_angle': {'__ndarray__': 'eWh3JypD8D/Iyt29krLkPz+JmVmivdE/TAwiIoOnt79nj6rqY5Hdv95NZoZznOq/A6q7ixo4878ZLURU+yH5vy2wzBzcC/+/oJmqct56AsAr2+7Wzm8FwLUcMzu/ZAjAP153n69ZC8DJn7sDoE4OwKvw/zPIoRDAbxEiZkAcEsA=',
#           'shape': (16,),
#           'dtype': 'float64'},
#          'end_angle': {'__ndarray__': 'eWh3JypD8D/Iyt29krLkPz+JmVmivdE/TAwiIoOnt79nj6rqY5Hdv95NZoZznOq/A6q7ixo4878ZLURU+yH5vy2wzBzcC/+/oJmqct56AsAr2+7Wzm8FwLUcMzu/ZAjAP153n69ZC8DJn7sDoE4OwKvw/zPIoRDAbxEiZkAcEsA=',
#           'shape': (16,),
#           'dtype': 'float64'}},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         selected=bokeh.models.selections.Selection(
#             id='bfcb3c6b-4cb8-4741-a453-1124b321f438',
#             indices=[],
#             js_event_callbacks={},
#             js_property_callbacks={},
#             line_indices=[],
#             multiline_indices={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         selection_policy=bokeh.models.selections.UnionRenderers(
#             id='13866c8e-e83b-4d9c-9b44-590e1edf3c9e',
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     glyph=bokeh.models.glyphs.AnnularWedge(
#         id='16289bee-b8f7-44cd-be61-104ba4835ba2',
#         direction='anticlock',
#         end_angle={'field': 'end_angle', 'units': 'rad'},
#         fill_alpha={'value': 1.0},
#         fill_color={'value': 'black'},
#         inner_radius={'value': 80, 'units': 'data'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha={'value': 1.0},
#         line_cap='butt',
#         line_color={'value': 'black'},
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='bevel',
#         line_width={'value': 1},
#         name=None,
#         outer_radius={'value': 300, 'units': 'data'},
#         start_angle={'field': 'start_angle', 'units': 'rad'},
#         subscribed_events=[],
#         tags=[],
#         x={'value': 0},
#         y={'value': 0}),
#     hover_glyph=None,
#     js_event_callbacks={},
#     js_property_callbacks={},
#     level='glyph',
#     muted=False,
#     muted_glyph=None,
#     name=None,
#     nonselection_glyph=bokeh.models.glyphs.AnnularWedge(
#         id='12792a8c-f60f-44ee-9b4d-2b4f8b187da6',
#         direction='anticlock',
#         end_angle={'field': 'end_angle', 'units': 'rad'},
#         fill_alpha={'value': 0.1},
#         fill_color={'value': '#1f77b4'},
#         inner_radius={'value': 80, 'units': 'data'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha={'value': 0.1},
#         line_cap='butt',
#         line_color={'value': '#1f77b4'},
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='bevel',
#         line_width={'value': 1},
#         name=None,
#         outer_radius={'value': 300, 'units': 'data'},
#         start_angle={'field': 'start_angle', 'units': 'rad'},
#         subscribed_events=[],
#         tags=[],
#         x={'value': 0},
#         y={'value': 0}),
#     selection_glyph=None,
#     subscribed_events=[],
#     tags=[],
#     view=bokeh.models.sources.CDSView(
#         id='3c096092-d34c-45a7-9186-151f330e2d74',
#         filters=[],
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         source=bokeh.models.sources.ColumnDataSource(
#             id='67980bc7-b1fa-4430-9db0-510b3b578259',
#             callback=None,
#             data={'start_angle': {'__ndarray__': 'eWh3JypD8D/Iyt29krLkPz+JmVmivdE/TAwiIoOnt79nj6rqY5Hdv95NZoZznOq/A6q7ixo4878ZLURU+yH5vy2wzBzcC/+/oJmqct56AsAr2+7Wzm8FwLUcMzu/ZAjAP153n69ZC8DJn7sDoE4OwKvw/zPIoRDAbxEiZkAcEsA=',
#               'shape': (16,),
#               'dtype': 'float64'},
#              'end_angle': {'__ndarray__': 'eWh3JypD8D/Iyt29krLkPz+JmVmivdE/TAwiIoOnt79nj6rqY5Hdv95NZoZznOq/A6q7ixo4878ZLURU+yH5vy2wzBzcC/+/oJmqct56AsAr2+7Wzm8FwLUcMzu/ZAjAP153n69ZC8DJn7sDoE4OwKvw/zPIoRDAbxEiZkAcEsA=',
#               'shape': (16,),
#               'dtype': 'float64'}},
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             selected=bokeh.models.selections.Selection(
#                 id='bfcb3c6b-4cb8-4741-a453-1124b321f438',
#                 indices=[],
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 line_indices=[],
#                 multiline_indices={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             selection_policy=bokeh.models.selections.UnionRenderers(
#                 id='13866c8e-e83b-4d9c-9b44-590e1edf3c9e',
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     visible=True,
#     x_range_name='default',
#     y_range_name='default')

# %%
# bacteria labels
xr = radii[0]*np.cos(np.array(-big_angle/2 + angles))
yr = radii[0]*np.sin(np.array(-big_angle/2 + angles))
label_angle=np.array(-big_angle/2+angles)
label_angle[label_angle < -np.pi/2] += np.pi # easier to read labels on the left side
p.text(xr, yr, df.bacteria, angle=label_angle, text_font_size="9pt", text_align="center", text_baseline="middle")
# Out:
# bokeh.models.renderers.GlyphRenderer(
#     id='95c8e508-fbff-4d69-9101-ac62bdfa2a63',
#     data_source=bokeh.models.sources.ColumnDataSource(
#         id='040182bc-0783-478d-bf6d-c295db22dd65',
#         callback=None,
#         data={'x': {'__ndarray__': 'cGn7M6UwWkAzVkZE5WtoQKq2lcOOOXBAjuBL4jQMckDOGdT43m5xQMF6BpGZ7WxA7SBXXEoVY0AXTcs3yKRKQBFNyzfIpErA6CBXXEoVY8DBegaRme1swM4Z1PjebnHAj+BL4jQMcsCrtpXDjjlwwDJWRkTla2jAcmn7M6UwWsA=',
#           'shape': (16,),
#           'dtype': 'float64'},
#          'y': {'__ndarray__': 'aywf0KvmcEAmrFe0AMpqQKfycbJzKGBAv6EJxQDCOkC6LG9iL9dTwNZbjg1z2GXAdpVS2APSbsAYUkjE/tBxwBhSSMT+0HHAepVS2APSbsDWW44Nc9hlwL8sb2Iv11PAmaEJxQDCOkCi8nGycyhgQCesV7QAympAaywf0KvmcEA=',
#           'shape': (16,),
#           'dtype': 'float64'},
#          'angle': {'__ndarray__': 'BKq7ixo48z/dTWaGc5zqP2iPqupjkd0/WgwiIoOntz8+iZlZor3Rv8nK3b2SsuS/eGh3JypD8L+O6//vCi32v47r/+8KLfY/emh3JypD8D/Iyt29krLkP0CJmVmivdE/QAwiIoOnt79gj6rqY5Hdv+BNZoZznOq/BKq7ixo4878=',
#           'shape': (16,),
#           'dtype': 'float64'},
#          'text': ['Mycobacterium tuberculosis',
#           'Salmonella schottmuelleri',
#           'Proteus vulgaris',
#           'Klebsiella pneumoniae',
#           'Brucella abortus',
#           'Pseudomonas aeruginosa',
#           'Escherichia coli',
#           'Salmonella (Eberthella) typhosa',
#           'Aerobacter aerogenes',
#           'Brucella antracis',
#           'Streptococcus fecalis',
#           'Staphylococcus aureus',
#           'Staphylococcus albus',
#           'Streptococcus hemolyticus',
#           'Streptococcus viridans',
#           'Diplococcus pneumoniae']},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         selected=bokeh.models.selections.Selection(
#             id='f3b12cad-ff03-4c14-ad19-272500d4025c',
#             indices=[],
#             js_event_callbacks={},
#             js_property_callbacks={},
#             line_indices=[],
#             multiline_indices={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         selection_policy=bokeh.models.selections.UnionRenderers(
#             id='a1b7fc46-44d6-488c-bc99-807b2185fd61',
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     glyph=bokeh.models.glyphs.Text(
#         id='8bf662c6-d164-46e0-b031-a509b37fbbda',
#         angle={'field': 'angle', 'units': 'rad'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         subscribed_events=[],
#         tags=[],
#         text={'field': 'text'},
#         text_align='center',
#         text_alpha={'value': 1.0},
#         text_baseline='middle',
#         text_color={'value': 'black'},
#         text_font='helvetica',
#         text_font_size={'value': '9pt'},
#         text_font_style='normal',
#         text_line_height=1.2,
#         x={'field': 'x'},
#         x_offset={'value': 0},
#         y={'field': 'y'},
#         y_offset={'value': 0}),
#     hover_glyph=None,
#     js_event_callbacks={},
#     js_property_callbacks={},
#     level='glyph',
#     muted=False,
#     muted_glyph=None,
#     name=None,
#     nonselection_glyph=bokeh.models.glyphs.Text(
#         id='6c751b0f-6060-4e20-b199-67374a1dad54',
#         angle={'field': 'angle', 'units': 'rad'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         subscribed_events=[],
#         tags=[],
#         text={'field': 'text'},
#         text_align='center',
#         text_alpha={'value': 0.1},
#         text_baseline='middle',
#         text_color={'value': 'black'},
#         text_font='helvetica',
#         text_font_size={'value': '9pt'},
#         text_font_style='normal',
#         text_line_height=1.2,
#         x={'field': 'x'},
#         x_offset={'value': 0},
#         y={'field': 'y'},
#         y_offset={'value': 0}),
#     selection_glyph=None,
#     subscribed_events=[],
#     tags=[],
#     view=bokeh.models.sources.CDSView(
#         id='2ac8a682-445a-442b-aac7-94f700d27add',
#         filters=[],
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         source=bokeh.models.sources.ColumnDataSource(
#             id='040182bc-0783-478d-bf6d-c295db22dd65',
#             callback=None,
#             data={'x': {'__ndarray__': 'cGn7M6UwWkAzVkZE5WtoQKq2lcOOOXBAjuBL4jQMckDOGdT43m5xQMF6BpGZ7WxA7SBXXEoVY0AXTcs3yKRKQBFNyzfIpErA6CBXXEoVY8DBegaRme1swM4Z1PjebnHAj+BL4jQMcsCrtpXDjjlwwDJWRkTla2jAcmn7M6UwWsA=',
#               'shape': (16,),
#               'dtype': 'float64'},
#              'y': {'__ndarray__': 'aywf0KvmcEAmrFe0AMpqQKfycbJzKGBAv6EJxQDCOkC6LG9iL9dTwNZbjg1z2GXAdpVS2APSbsAYUkjE/tBxwBhSSMT+0HHAepVS2APSbsDWW44Nc9hlwL8sb2Iv11PAmaEJxQDCOkCi8nGycyhgQCesV7QAympAaywf0KvmcEA=',
#               'shape': (16,),
#               'dtype': 'float64'},
#              'angle': {'__ndarray__': 'BKq7ixo48z/dTWaGc5zqP2iPqupjkd0/WgwiIoOntz8+iZlZor3Rv8nK3b2SsuS/eGh3JypD8L+O6//vCi32v47r/+8KLfY/emh3JypD8D/Iyt29krLkP0CJmVmivdE/QAwiIoOnt79gj6rqY5Hdv+BNZoZznOq/BKq7ixo4878=',
#               'shape': (16,),
#               'dtype': 'float64'},
#              'text': ['Mycobacterium tuberculosis',
#               'Salmonella schottmuelleri',
#               'Proteus vulgaris',
#               'Klebsiella pneumoniae',
#               'Brucella abortus',
#               'Pseudomonas aeruginosa',
#               'Escherichia coli',
#               'Salmonella (Eberthella) typhosa',
#               'Aerobacter aerogenes',
#               'Brucella antracis',
#               'Streptococcus fecalis',
#               'Staphylococcus aureus',
#               'Staphylococcus albus',
#               'Streptococcus hemolyticus',
#               'Streptococcus viridans',
#               'Diplococcus pneumoniae']},
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             selected=bokeh.models.selections.Selection(
#                 id='f3b12cad-ff03-4c14-ad19-272500d4025c',
#                 indices=[],
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 line_indices=[],
#                 multiline_indices={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             selection_policy=bokeh.models.selections.UnionRenderers(
#                 id='a1b7fc46-44d6-488c-bc99-807b2185fd61',
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     visible=True,
#     x_range_name='default',
#     y_range_name='default')

# %%
# OK, these hand drawn legends are pretty clunky, will be improved in future release
p.circle([-40, -40], [-370, -390], color=list(gram_color.values()), radius=5)
p.text([-30, -30], [-370, -390], text=["Gram-" + x for x in gram_color.keys()], 
       text_font_size="7pt", text_align="left", text_baseline="middle")

p.rect([-40, -40, -40], [18, 0, -18], width=30, height=13, color=list(drug_color.values()))
p.text([-15, -15, -15], [18, 0, -18], text=list(drug_color.keys()),
       text_font_size="9pt", text_align="left", text_baseline="middle")
# Out:
# bokeh.models.renderers.GlyphRenderer(
#     id='fc08375f-0be9-4d4f-a6e8-09fd0cd138eb',
#     data_source=bokeh.models.sources.ColumnDataSource(
#         id='d1587f86-4242-432b-8f16-7fa48057f951',
#         callback=None,
#         data={'x': [-15, -15, -15],
#          'y': [18, 0, -18],
#          'text': ['Penicillin', 'Streptomycin', 'Neomycin']},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         selected=bokeh.models.selections.Selection(
#             id='b8d3f32b-73e7-4f14-a501-973fde02b030',
#             indices=[],
#             js_event_callbacks={},
#             js_property_callbacks={},
#             line_indices=[],
#             multiline_indices={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         selection_policy=bokeh.models.selections.UnionRenderers(
#             id='8b1ae854-7217-44f3-a0e7-ee433e353699',
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     glyph=bokeh.models.glyphs.Text(
#         id='512364fd-bf4f-4801-9224-cd13698d65ca',
#         angle={'value': 0, 'units': 'rad'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         subscribed_events=[],
#         tags=[],
#         text={'field': 'text'},
#         text_align='left',
#         text_alpha={'value': 1.0},
#         text_baseline='middle',
#         text_color={'value': 'black'},
#         text_font='helvetica',
#         text_font_size={'value': '9pt'},
#         text_font_style='normal',
#         text_line_height=1.2,
#         x={'field': 'x'},
#         x_offset={'value': 0},
#         y={'field': 'y'},
#         y_offset={'value': 0}),
#     hover_glyph=None,
#     js_event_callbacks={},
#     js_property_callbacks={},
#     level='glyph',
#     muted=False,
#     muted_glyph=None,
#     name=None,
#     nonselection_glyph=bokeh.models.glyphs.Text(
#         id='df1e218f-a845-45ba-80c4-bf0dcb313544',
#         angle={'value': 0, 'units': 'rad'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         subscribed_events=[],
#         tags=[],
#         text={'field': 'text'},
#         text_align='left',
#         text_alpha={'value': 0.1},
#         text_baseline='middle',
#         text_color={'value': 'black'},
#         text_font='helvetica',
#         text_font_size={'value': '9pt'},
#         text_font_style='normal',
#         text_line_height=1.2,
#         x={'field': 'x'},
#         x_offset={'value': 0},
#         y={'field': 'y'},
#         y_offset={'value': 0}),
#     selection_glyph=None,
#     subscribed_events=[],
#     tags=[],
#     view=bokeh.models.sources.CDSView(
#         id='82130c55-4100-4591-96b6-bf4c9130edf8',
#         filters=[],
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         source=bokeh.models.sources.ColumnDataSource(
#             id='d1587f86-4242-432b-8f16-7fa48057f951',
#             callback=None,
#             data={'x': [-15, -15, -15],
#              'y': [18, 0, -18],
#              'text': ['Penicillin', 'Streptomycin', 'Neomycin']},
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             selected=bokeh.models.selections.Selection(
#                 id='b8d3f32b-73e7-4f14-a501-973fde02b030',
#                 indices=[],
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 line_indices=[],
#                 multiline_indices={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             selection_policy=bokeh.models.selections.UnionRenderers(
#                 id='8b1ae854-7217-44f3-a0e7-ee433e353699',
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     visible=True,
#     x_range_name='default',
#     y_range_name='default')

# %%
p.xgrid.grid_line_color = None
p.ygrid.grid_line_color = None

# %%
show(p)
# Out:
#   <div class="bk-root" id="79cf6f8b-45da-419c-b73a-dd853bdf23b4"></div>

# %%
import numpy as np

# %%
from bokeh.layouts import gridplot
from bokeh.plotting import figure, output_notebook, show
from bokeh.models import ColumnDataSource

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ab00e5ba-0f6e-4360-85e6-3fb73ab7a564">Loading BokehJS ...</span>
#     </div>

# %%
N = 300
x = np.linspace(0, 4*np.pi, N)
y1 = np.sin(x)
y2 = np.cos(x)

# %%
source = ColumnDataSource(data=dict(x=x, y1=y1, y2=y2))

# %%
TOOLS = "pan,wheel_zoom,box_zoom,reset,save,box_select,lasso_select"

s1 = figure(tools=TOOLS, plot_width=350, plot_height=350)
s1.scatter('x', 'y1', source=source)

# Linked brushing in Bokeh is expressed by sharing data sources between
# renderers. Note below that s2.scatter is called with the `source` 
# keyword argument, and supplied with the same data source from s1.scatter
s2 = figure(tools=TOOLS, plot_width=350, plot_height=350)
s2.circle('x', 'y2', source=source)
# Out:
# bokeh.models.renderers.GlyphRenderer(
#     id='95c3696a-7d3e-4b6d-b3a3-7314d6718080',
#     data_source=bokeh.models.sources.ColumnDataSource(
#         id='88cfd4da-1c5a-4cb5-8bd8-c9dac567b300',
#         callback=None,
#         data={'x': {'__ndarray__': '...',
#           'shape': (300,),
#           'dtype': 'float64'},
#          'y2': {'__ndarray__': '...',
#           'shape': (300,),
#           'dtype': 'float64'},
#          'y1': {'__ndarray__': '...',
#           'shape': (300,),
#           'dtype': 'float64'}},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         selected=bokeh.models.selections.Selection(
#             id='1a3a6997-6dfe-4b3c-a93a-832d8b1e11e1',
#             indices=[],
#             js_event_callbacks={},
#             js_property_callbacks={},
#             line_indices=[],
#             multiline_indices={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         selection_policy=bokeh.models.selections.UnionRenderers(
#             id='2f5460ae-7fb5-45fa-b6d7-60b7e7dd9571',
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     glyph=bokeh.models.markers.Circle(
#         id='16b2a1dc-805e-48f4-9ce0-577e9535e0cf',
#         angle={'value': 0.0, 'units': 'rad'},
#         fill_alpha={'value': 1.0},
#         fill_color={'value': '#1f77b4'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha={'value': 1.0},
#         line_cap='butt',
#         line_color={'value': '#1f77b4'},
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='bevel',
#         line_width={'value': 1},
#         name=None,
#         radius=None,
#         radius_dimension='x',
#         size={'value': 4, 'units': 'screen'},
#         subscribed_events=[],
#         tags=[],
#         x={'field': 'x'},
#         y={'field': 'y2'}),
#     hover_glyph=None,
#     js_event_callbacks={},
#     js_property_callbacks={},
#     level='glyph',
#     muted=False,
#     muted_glyph=None,
#     name=None,
#     nonselection_glyph=bokeh.models.markers.Circle(
#         id='9f512bd3-8273-4aa1-9028-c89e0cce30bd',
#         angle={'value': 0.0, 'units': 'rad'},
#         fill_alpha={'value': 0.1},
#         fill_color={'value': '#1f77b4'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha={'value': 0.1},
#         line_cap='butt',
#         line_color={'value': '#1f77b4'},
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='bevel',
#         line_width={'value': 1},
#         name=None,
#         radius=None,
#         radius_dimension='x',
#         size={'value': 4, 'units': 'screen'},
#         subscribed_events=[],
#         tags=[],
#         x={'field': 'x'},
#         y={'field': 'y2'}),
#     selection_glyph=None,
#     subscribed_events=[],
#     tags=[],
#     view=bokeh.models.sources.CDSView(
#         id='36f4c667-99f9-4dad-b309-55b78596af57',
#         filters=[],
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         source=bokeh.models.sources.ColumnDataSource(
#             id='88cfd4da-1c5a-4cb5-8bd8-c9dac567b300',
#             callback=None,
#             data={'x': {'__ndarray__': '...',
#               'shape': (300,),
#               'dtype': 'float64'},
#              'y2': {'__ndarray__': '...',
#               'shape': (300,),
#               'dtype': 'float64'},
#              'y1': {'__ndarray__': '...',
#               'shape': (300,),
#               'dtype': 'float64'}},
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             selected=bokeh.models.selections.Selection(
#                 id='1a3a6997-6dfe-4b3c-a93a-832d8b1e11e1',
#                 indices=[],
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 line_indices=[],
#                 multiline_indices={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             selection_policy=bokeh.models.selections.UnionRenderers(
#                 id='2f5460ae-7fb5-45fa-b6d7-60b7e7dd9571',
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     visible=True,
#     x_range_name='default',
#     y_range_name='default')

# %%
p = gridplot([[s1,s2]])
show(p)
# Out:
#   <div class="bk-root" id="1091475d-5e4b-4b5f-a9f3-960597967c38"></div>
